# %%
import pandas as pd
import numpy as np
import pickle
from nltk.stem.porter import PorterStemmer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import sys

# %%
electronics = pd.read_csv("data/All Electronics.csv")

# %%
electronics.duplicated().sum()
# Out:
# 0

# %%
electronics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9600 entries, 0 to 9599
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            9600 non-null   object
#  1   main_category   9600 non-null   object
#  2   sub_category    9600 non-null   object
#  3   image           9600 non-null   object
#  4   link            9600 non-null   object
#  5   ratings         9505 non-null   object
#  6   no_of_ratings   9505 non-null   object
#  7   discount_price  9116 non-null   object
#  8   actual_price    9530 non-null   object
# dtypes: object(9)
# memory usage: 675.1+ KB

# %%
electronics.isna().sum()
# Out:
# name                0
# main_category       0
# sub_category        0
# image               0
# link                0
# ratings            95
# no_of_ratings      95
# discount_price    484
# actual_price       70
# dtype: int64

# %%
electronics.drop(['main_category','sub_category'],axis=1,inplace=True)

# %%
electronics.to_csv("data/processed.csv")

# %%
# Create test_processor.py
from recommender.data_processor import preprocess_data

df = preprocess_data("data/processed.csv")
print("Shape:", df.shape)
print("\nSample tags:")
print(df[['name', 'tags']].head(3))
# Out:
# INFO - data_processor - Checking for required NLTK data
# INFO - data_processor - Downloading NLTK punkt tokenizer
# INFO - data_processor - NLTK punkt tokenizer downloaded
# INFO - data_processor - Starting preprocessing pipeline for data/processed.csv
# INFO - data_processor - Loading data from data/processed.csv
# INFO - data_processor - Data loaded successfully. Shape: (9600, 8), Columns: ['Unnamed: 0', 'name', 'image', 'link', 'ratings', 'no_of_ratings', 'discount_price', 'actual_price']
# INFO - data_processor - Organizing keywords for dataframe with shape (9600, 8)
# INFO - data_processor - Keywords organized. 9600/9600 products have non-empty tags
# INFO - data_processor - Preprocessing pipeline completed successfully
# Shape: (9600, 9)
#
# Sample tags:
#                                                 name  \
# 0  Redmi 10 Power (Power Black, 8GB RAM, 128GB St...
# 1  OnePlus Nord CE 2 Lite 5G (Blue Tide, 6GB RAM,...
# 2  OnePlus Bullets Z2 Bluetooth Wireless in Ear E...
#
# ...
